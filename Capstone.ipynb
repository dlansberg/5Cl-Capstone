# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def absorption_coefficient(A, C, l):
    # A = Absorption
    # C = concentration
    # l = path length
    epsilon = A/(C*l)

# %%
def f(x,m):
    return x*m

# %%
l =
C = np.array([])
x = C*l

I0 =
I = np.array([])
y = log(I/I0)

p0 = [0]

parameters, covariance_matrix = fit.curve_fit(f,x,y,p0=p0)
# Out:
#   Cell In[4], line 1
#     l =
#        ^
# SyntaxError: invalid syntax

# %%
m_error = np.sqrt(covariance_matrix[0])
m_pred = parameters[0]

plt.figure()

x_pred = np.linspace(min(x), max(x), 200)
y_pred = f(x_pred, m_pred)

plt.plot(x_pred,y_pred,color = 'red',label = f' A = {np.round(m_pred,8)}±{np.round(m_error,8)} C*l')
plt.title('Absorbance vs. Concentration (mol/L) * Path Length (cm)')
plt.legend()

plt.scatter(x,y)
plt.ylabel('Absorbance (Log(I/Io))')
plt.xlabel('Concentration (mol/L) * Path Length (cm)')
plt.savefig('Capstone_Epsilon.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 m_error = np.sqrt(covariance_matrix[0])
#       2 m_pred = parameters[0]
#       4 plt.figure()
#
# NameError: name 'covariance_matrix' is not defined

# %%
data1 = pd.read_csv('trial_1.csv')
data1 = data1.iloc[:, :2]

data2 = pd.read_csv('trial_2.csv')
data2 = data2.iloc[:, :2]

data3 = pd.read_csv('trial_3.csv')
data3 = data3.iloc[:, :2]

data4 = pd.read_csv('trial_4.csv')
data4 = data4.iloc[:, :2]

data5 = pd.read_csv('trial_5.csv')
data5 = data5.iloc[:, :2]

intensity = [data1['Intensity Source #2'],data2['Intensity Source #3'],data3['Intensity Source #4'],data4['Intensity Source #5'],data5['Intensity Source #6']]
#data2

# %%
for i in range(len(intensity)):
    print(f'data {i} = {max(intensity[i])}')
# Out:
# data 0 = 72.495
# data 1 = 72.571
# data 2 = 79.588
# data 3 = 88.136
# data 4 = 80.11

# %%
#path length for KCl
